# %% [markdown]
# # 可视化
#
# matplotlib: https://matplotlib.org/stable/users/index.html
# 在jupyter中
# > %matplotlib inline # 静态图形
# >
# > %matplotlib widget # 交互式图形

# %% [markdown]
# 线形图

# %% [markdown]
# 散点图

# %% [markdown]
# |API|Reference|Description|
# |---|----|---|
# |`plot()`|||
# |`scatter()`|matplotlib.axes.Axes, matplotlib.pyplot||
