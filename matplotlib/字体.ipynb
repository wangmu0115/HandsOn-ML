# %%
import matplotlib.font_manager as fm

# %%
# show all fonts
for font in fm.fontManager.ttflist:
    if "kaiti" in font.name.lower():
        print(f"name: {font.name}, path: {font.fname}")
# Out:
# name: Kaiti SC, path: /System/Library/AssetsV2/com_apple_MobileAsset_Font7/54a2ad3dac6cac875ad675d7d273dc425010a877.asset/AssetData/Kaiti.ttc

# %%
mpl.rcParams["font.sans-serif"] = ["Kaiti SC", "Menlo"] # 设置字体，防止中文无法显示
