# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import add_dummy_feature

# %%
rng = np.random.default_rng(42)

m = 100 # 样本数量

X = 2 * rng.uniform(size=(m, 1))
y = 4 + 3 * X + rng.normal(size=(m, 1))

plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], y[:, 0], s=10.0, c="blue")
plt.ylim(0, max(y[:, 0]) + 1.0)
plt.grid(True)
plt.show()

# %%
X_b = add_dummy_feature(X)

# %%
w_best = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

# %%
w_best
# Out:
# array([[3.94869973],
#        [3.03831479]])

# %%
X_new = np.array([[0], [2]])
X_new_b = add_dummy_feature(X_new)
y_predict = X_new_b @ w_best
y_predict
# Out:
# array([[ 3.94869973],
#        [10.02532931]])

# %%
plt.plot(X_new, y_predict, "r-", label="Predictions")
plt.plot(X, y, "b.")
plt.ylim(0, max(y) + 1.0)
plt.grid(True)
plt.show()
