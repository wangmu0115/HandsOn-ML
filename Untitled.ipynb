# %%
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.decomposition import PCA, KernelPCA
from sklearn.feature_selection import SelectKBest
from sklearn.linear_model import LogisticRegression

union = FeatureUnion([("pca", PCA()), ("kpca", KernelPCA(kernel="rbf"))])
Pipeline([
    ("feature_union", union),
    ("feature_sel", SelectKBest(k=10)),
    ("log_reg", LogisticRegression(penalty="l2")),
]).fit(X_train, y_train).predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       3 from sklearn.feature_selection import SelectKBest
#       5 union = FeatureUnion([("pca", PCA()), ("kpca", KernelPCA(kernel="rbf"))])
#       6 Pipeline([
#       7     (),
#       8     (),
#       9     (),
# ---> 10 ]).fit(X_train, y_train).predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid = [
    {"kernel": ["linear"], "C": [1, 10, 100, 1000]},
    {"kernel": ["rbf"], "C": [1, 10, 100, 1000], "gamma": [0.001, 0.0001]},    
]
clf = GridSearchCV(SVC(), param_grid, scoring="f1", cv=10)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       4 param_grid = [
#       5     {"kernel": ["linear"], "C": [1, 10, 100, 1000]},
#       6     {"kernel": ["rbf"], "C": [1, 10, 100, 1000], "gamma": [0.001, 0.0001]},
#       7 ]
#       8 clf = GridSearchCV(SVC(), param_grid, scoring="f1", cv=10)
# ----> 9 clf.fit(X_train, y_train)
#      10 y_pred = clf.predict(X_test)
#
# NameError: name 'X_train' is not defined
