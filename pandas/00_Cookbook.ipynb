# %% [markdown]
# ## 数据结构
#
# **Series** 是一个一维带标签的数组，可以存储任意数据类型，轴标签称为索引（index）。
#
# `pd.Series(data [,index ,dtype ,name])`
#
# **DataFrame** 是一个二维带标签的数组，每一列可能包含不同类型的数据，行标签称为索引（index），列标签称为列（columns）。
#
# `pd.DataFrame(data [,index ,columns ,dtype])`
